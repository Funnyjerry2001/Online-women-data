# %%
import pandas as pd

# %%
records = pd.read_csv("Online_Learning_Data.csv")

# %%
records
# Out:
#        Month  Argentina  Brazil  Colombia  France  Germany  India  Indonesia  \
# 0    2004-01          0       0         0       0       35     44          0
# 1    2004-02        100       0         0      43       38     59         41
# 2    2004-03          0      90         0       0       48     74          0
# 3    2004-04          0       0         0       0       39     72         39
# 4    2004-05          0       0         0       0       34     24        100
# ..       ...        ...     ...       ...     ...      ...    ...        ...
# 209  2021-06          4       9        15       8       31     24          8
# 210  2021-07          5       6        15       8       44     21          7
# 211  2021-08          9       7        11      10       32     18          4
# 212  2021-09          5       6        15       6       47     17          8
# 213  2021-10         20       4        11       7       20     15         11
#
# ...

# %%
records.columns
# Out:
# Index(['Month', 'Argentina', 'Brazil', 'Colombia', 'France', 'Germany',
#        'India', 'Indonesia', 'Iran', 'Italy', 'Mexico', 'Peru', 'Philippines',
#        'Poland', 'Russia', 'South Africa', 'Spain', 'Turkey', 'Ukraine',
#        'United Kingdom', 'United States of America'],
#       dtype='object')

# %%
## record.duplicated

# %%
## insert a new column named "Year"

#position, column name, values

# %%
records.dtypes
# Out:
# Month                       object
# Argentina                    int64
# Brazil                       int64
# Colombia                     int64
# France                       int64
# Germany                      int64
# India                        int64
# Indonesia                    int64
# Iran                         int64
# Italy                        int64
# Mexico                       int64
# Peru                         int64
# Philippines                  int64
# Poland                       int64
# Russia                       int64
# South Africa                 int64
# Spain                        int64
# Turkey                       int64
# Ukraine                      int64
# United Kingdom               int64
# United States of America     int64
# dtype: object

# %%
records['Month'].astype('datetime64[ns]')
# Out:
# 0     2004-01-01
# 1     2004-02-01
# 2     2004-03-01
# 3     2004-04-01
# 4     2004-05-01
#          ...
# 209   2021-06-01
# 210   2021-07-01
# 211   2021-08-01
# 212   2021-09-01
# 213   2021-10-01
# Name: Month, Length: 214, dtype: datetime64[ns]

# %%
records['Month']=records['Month'].astype('datetime64[ns]')
records
# Out:
#          Month  Argentina  Brazil  Colombia  France  Germany  India  \
# 0   2004-01-01          0       0         0       0       35     44
# 1   2004-02-01        100       0         0      43       38     59
# 2   2004-03-01          0      90         0       0       48     74
# 3   2004-04-01          0       0         0       0       39     72
# 4   2004-05-01          0       0         0       0       34     24
# ..         ...        ...     ...       ...     ...      ...    ...
# 209 2021-06-01          4       9        15       8       31     24
# 210 2021-07-01          5       6        15       8       44     21
# 211 2021-08-01          9       7        11      10       32     18
# 212 2021-09-01          5       6        15       6       47     17
# 213 2021-10-01         20       4        11       7       20     15
#
#      Indonesia  Iran  Italy  ...  Peru  Philippines  Poland  Russia  \
# 0            0     0      0  ...     0            0       0     100
# ...

# %%
#to insert a new column before month , name the column year
records['Month'].dt.to_period('y')
# Out:
# 0      2004
# 1      2004
# 2      2004
# 3      2004
# 4      2004
#        ...
# 209    2021
# 210    2021
# 211    2021
# 212    2021
# 213    2021
# Name: Month, Length: 214, dtype: period[A-DEC]

# %%
records
# Out:
#          Month  Argentina  Brazil  Colombia  France  Germany  India  \
# 0   2004-01-01          0       0         0       0       35     44
# 1   2004-02-01        100       0         0      43       38     59
# 2   2004-03-01          0      90         0       0       48     74
# 3   2004-04-01          0       0         0       0       39     72
# 4   2004-05-01          0       0         0       0       34     24
# ..         ...        ...     ...       ...     ...      ...    ...
# 209 2021-06-01          4       9        15       8       31     24
# 210 2021-07-01          5       6        15       8       44     21
# 211 2021-08-01          9       7        11      10       32     18
# 212 2021-09-01          5       6        15       6       47     17
# 213 2021-10-01         20       4        11       7       20     15
#
#      Indonesia  Iran  Italy  ...  Peru  Philippines  Poland  Russia  \
# 0            0     0      0  ...     0            0       0     100
# ...

# %%
records.insert(0,"Year","")

# %%
records
# Out:
#     Year      Month  Argentina  Brazil  Colombia  France  Germany  India  \
# 0        2004-01-01          0       0         0       0       35     44
# 1        2004-02-01        100       0         0      43       38     59
# 2        2004-03-01          0      90         0       0       48     74
# 3        2004-04-01          0       0         0       0       39     72
# 4        2004-05-01          0       0         0       0       34     24
# ..   ...        ...        ...     ...       ...     ...      ...    ...
# 209      2021-06-01          4       9        15       8       31     24
# 210      2021-07-01          5       6        15       8       44     21
# 211      2021-08-01          9       7        11      10       32     18
# 212      2021-09-01          5       6        15       6       47     17
# 213      2021-10-01         20       4        11       7       20     15
#
#      Indonesia  Iran  ...  Peru  Philippines  Poland  Russia  South Africa  \
# ...

# %%
records["Year"]=records['Month'].dt.to_period('y')

# %%
records
# Out:
#      Year      Month  Argentina  Brazil  Colombia  France  Germany  India  \
# 0    2004 2004-01-01          0       0         0       0       35     44
# 1    2004 2004-02-01        100       0         0      43       38     59
# 2    2004 2004-03-01          0      90         0       0       48     74
# 3    2004 2004-04-01          0       0         0       0       39     72
# 4    2004 2004-05-01          0       0         0       0       34     24
# ..    ...        ...        ...     ...       ...     ...      ...    ...
# 209  2021 2021-06-01          4       9        15       8       31     24
# 210  2021 2021-07-01          5       6        15       8       44     21
# 211  2021 2021-08-01          9       7        11      10       32     18
# 212  2021 2021-09-01          5       6        15       6       47     17
# 213  2021 2021-10-01         20       4        11       7       20     15
#
#      Indonesia  Iran  ...  Peru  Philippines  Poland  Russia  South Africa  \
# ...

# %%
records['Year'].unique()
# Out:
# <PeriodArray>
# ['2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012',
#  '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021']
# Length: 18, dtype: period[A-DEC]

# %%
records.groupby('Year').sum(numeric_only="True").reset_index()
# Out:
#     Year  Argentina  Brazil  Colombia  France  Germany  India  Indonesia  \
# 0   2004        100     190         0     235      585    529        250
# 1   2005         38      63       178     126      455    797        140
# 2   2006         73      63         0     183      515    636         81
# 3   2007         85     110        96     166      550    527         94
# 4   2008         35      98       107     109      607    461         41
# 5   2009         18      95        59     132      490    449         68
# 6   2010         37      60        45      98      508    365         51
# 7   2011         33      89        54     118      346    313         25
# 8   2012         32      68       109      92      431    284         29
# 9   2013         33      74       103      91      381    278         21
# 10  2014         27      86        76      78      490    254         18
# 11  2015         35      83        47      91      404    261         20
# ...

# %%
records["Year"] = records["Year"].dt.to_timestamp()

# %%
a=records.groupby('Year').sum(numeric_only="True").reset_index()

# %%
import plotly.express as px

# %%
px.line(a, x="Year", y="Germany", title= "Line chart",text="Germany")
# Out:
# <div>                            <div id="23f3050d-b958-4bda-bffb-2b3ba3997fab" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("23f3050d-b958-4bda-bffb-2b3ba3997fab")) {                    Plotly.newPlot(                        "23f3050d-b958-4bda-bffb-2b3ba3997fab",                        [{"hovertemplate":"Year=%{x}<br>Germany=%{text}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers+text","name":"","orientation":"v","showlegend":false,"text":[585.0,455.0,515.0,550.0,607.0,490.0,508.0,346.0,431.0,381.0,490.0,404.0,448.0,542.0,423.0,458.0,632.0,450.0],"x":["2004-01-01T00:00:00","2005-01-01T00:00:00","2006-01-01T00:00:00","2007-01-01T00:00:00","2008-01-01T00:00:00","2009-01-
# ...
